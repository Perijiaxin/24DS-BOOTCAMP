# %% [markdown]
# 1. From df filter the 'Manufacturer', 'Model' and 'Type' for every 20th row starting from 1st (row 0).

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')
df.head()
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0        Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1          NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2         Audi       90  Compact       25.9   29.1       32.3      20.0
# 3         Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4          BMW     535i  Midsize        NaN   30.0        NaN      22.0
#
#    MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 0         31.0                None      Front  ...        5.0   177.0
# 1         25.0  Driver & Passenger      Front  ...        5.0   195.0
# 2         26.0         Driver only      Front  ...        5.0   180.0
# 3         26.0  Driver & Passenger        NaN  ...        6.0   193.0
# 4         30.0                 NaN       Rear  ...        4.0   186.0
#
#    Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# ...

# %%
filtered_df = df.loc[::20, ['Manufacturer', 'Model', 'Type']]
print(filtered_df)
# Out:
#    Manufacturer    Model     Type
# 0         Acura  Integra    Small
# 20     Chrysler  LeBaron  Compact
# 40        Honda  Prelude   Sporty
# 60      Mercury   Cougar  Midsize
# 80       Subaru   Loyale    Small

# %% [markdown]
# 2. Replace missing values in Min.Price and Max.Price columns with their respective mean.

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')
df2.head()
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0        Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1          NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2         Audi       90  Compact       25.9   29.1       32.3      20.0
# 3         Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4          BMW     535i  Midsize        NaN   30.0        NaN      22.0
#
#    MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 0         31.0                None      Front  ...        5.0   177.0
# 1         25.0  Driver & Passenger      Front  ...        5.0   195.0
# 2         26.0         Driver only      Front  ...        5.0   180.0
# 3         26.0  Driver & Passenger        NaN  ...        6.0   193.0
# 4         30.0                 NaN       Rear  ...        4.0   186.0
#
#    Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# ...

# %%
mean_min_price = df2['Min.Price'].mean()
mean_max_price = df2['Max.Price'].mean()

# %%
df2['Min.Price'].fillna(mean_min_price, inplace=True)
df2['Max.Price'].fillna(mean_max_price, inplace=True)

# %%
df2.head()
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0        Acura  Integra    Small  12.900000   15.9  18.800000      25.0
# 1          NaN   Legend  Midsize  29.200000   33.9  38.700000      18.0
# 2         Audi       90  Compact  25.900000   29.1  32.300000      20.0
# 3         Audi      100  Midsize  17.118605   37.7  44.600000      19.0
# 4          BMW     535i  Midsize  17.118605   30.0  21.459091      22.0
#
#    MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 0         31.0                None      Front  ...        5.0   177.0
# 1         25.0  Driver & Passenger      Front  ...        5.0   195.0
# 2         26.0         Driver only      Front  ...        5.0   180.0
# 3         26.0  Driver & Passenger        NaN  ...        6.0   193.0
# 4         30.0                 NaN       Rear  ...        4.0   186.0
#
#    Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# ...

# %% [markdown]
# How to get the rows of a dataframe with row sum > 100?

# %%
df3 = pd.DataFrame(np.random.randint(10, 40, 60).reshape(-1, 4))
df3.head()
# Out:
#     0   1   2   3
# 0  18  10  29  30
# 1  32  28  29  13
# 2  30  31  31  27
# 3  25  31  35  24
# 4  26  35  11  14

# %%
row_sums = df3.sum(axis=1)
filtered_df3 = df3[row_sums > 100]
filtered_df3
# Out:
#      0   1   2   3
# 1   32  28  29  13
# 2   30  31  31  27
# 3   25  31  35  24
# 14  32  23  24  28

# %% [markdown]
# 4)Create a 4x4 NumPy array filled with random integers between 1 and 100. Then, reshape this array into two separate 2D arrays, where one represents the rows and the other represents the columns. Write a function, preferably using a lambda function, to calculate the sum of each row and each column separately, and return the results as two separate NumPy arrays

# %%
array_4x4 = np.random.randint(1, 100, (4, 4))

# %%
sum_rows = lambda arr: np.sum(arr, axis=1)
sum_cols = lambda arr: np.sum(arr, axis=0)

# %%
row_sums = sum_rows(array_4x4)
col_sums = sum_cols(array_4x4)

array_4x4, row_sums, col_sums
# Out:
# (array([[67, 45, 38, 29],
#         [78, 16, 23, 63],
#         [54, 70, 49, 44],
#         [65, 67,  9, 33]]),
#  array([179, 180, 217, 174]),
#  array([264, 198, 119, 169]))
